# %%
import urllib
import requests
import json

# %%
def getpage(pageNumber:int) -> dict:
    r = requests.get(f'https://external.api.yle.fi/v1/teletext/pages/{pageNumber}.json?app_id=ef64cfef&app_key=5b2b993030bbb3537a23f1a058cbbeda')
    if len(r.text)>0:
        return json.loads(r.text)
uutiset_kotimaa = 102
uutiset_ulkomaat = 130
uutiset_kotimaa = getpage(uutiset_kotimaa)
uutiset_ulkomaat = getpage(uutiset_ulkomaat)

# %%
news = {}
for newsPage in [uutiset_kotimaa, uutiset_ulkomaat]:
    for item in newsPage['teletext']['page']['subpage'][0]['content'][0]['line']:
        text_items = []
        if 'Text' in item.keys(): 
            textlist = item['Text'].split()
            for i, token in enumerate(textlist): 
                try:
                    num = int(token)
                    if not 'TALOUS' in textlist:
                        text_items.append([num, ' '.join(textlist[i+1:])])
                    #print(text_items)
                    break
                except ValueError: 
                    continue
        if len(text_items)==0: continue
        for pagenumber, headline in text_items: 
            newspage = getpage(pagenumber)
            if not newspage: continue
            count = 0
            result = []
            for item in newspage['teletext']['page']['subpage'][0]['content'][0]['line']: 
                if 'Text' in item.keys(): 
                    count += 1
                    if count  >2: 
                        result.append(item['Text'].strip())
            news.update({pagenumber: {'Name': headline, 'Text': result}})

# %%
for pagenumber, newsdict in news.items(): 
    print(f'-----{pagenumber}-----')
    for name, text in newsdict.items(): 
        jointext = ''.join(text)
        print(f'{jointext}\n')
# Out:
# -----103-----
# Marin: Ei Natoon, ainakaan vielä
#
# Pääministeri Sanna Marin (Sdp)  sanoikeskiviikkona uutistoimisto Reutersinhaastattelussa, että on "hyvinepätodennäköistä", että Suomi liittyisiNatoon hänen pääministerikaudellaan.Marinin mukaan Suomi pitää tiukastikiinni oikeudestaan liittyä Natoontulevaisuudessa, jos niin päätetään.- Kukaan ei pysty vaikuttamaan meihin.Ei Yhdysvallat, ei Venäjä eikä kukaanmuu. Uskon kuitenkin, ettäNato-keskustelut tulevat lisääntymääntulevina vuosina, Marin sanoi.
#
# -----104-----
# Itsemurhasuunnitelmat lisääntyneet
#
# Kriisipuhelimeen akuutissa itsemurha-vaarassa olevilta tulleiden soittojenmäärä on lähes kolmikertaistunutkoronapandemian aikana, kertoo MieliSuomen Mielenterveys ry tiedotteessaan.Viime syksynä Mieli ry:n Kriisipuheli-messa käytiin kuukaudessa lähes 120keskustelua, joissa päivystäjä arvioisoittajan olevan akuutissa itsemurha-vaarassa. Tällaisiksi lasketaan soitot,joissa soittaja on lähiaikoina yrittä-nyt itsemurhaa tai hänellä on valmisitsemurhasuunnitelma.Itsemurhien määrä ei ole kuitenkaanTilastokeskuksen tietojen mukaanlisääntynyt.
#
# -----105-----
# Ajokeli huononee lumipyryn vuoksi
#
# Ajokeli heikkenee tänään erittäinhuonoksi maan etelä- ja keskiosissa,varoittaa Ilmatieteen laitos. Varhaintorstaina alkanut lumisade jatkuuiltaan asti.Torstain sakeimmat lumipyryt tulevatVarsinais-Suomessa, Uudellamaalla jaHämeessä. Märkää lunta voi kertyä jopa10-15 senttiä etelässä ja lounaassa.Merialueille on annettu torstaiksikovan tuulen varoituksia. Aallokko- jamyrskyvaroituksia on annettulänsirannikon merialueille Merenkurkuneteläpuolella.
#
# -----106-----
# Ylen vaalikysely: Keskusta noussut
#
# Taloustutkimuksen Ylelle tekemässäpuolueiden aluevaalikannatustamittaavassa tutkimuksessa Keskustapomppasi SDP:n kannoille,perussuomalaiset vajosi ja kokoomusvahvisti kärkipaikkaansaKeskustan ja vihreiden vaaliasetelmiinvaikuttaa selkeästi se, ettähelsinkiläiset eivät äänestäaluevaaleissa.Kokoomus on kärjessä yli 22 prosentinkannatuksellaan.SDP:tä äänestäisi 18 prosenttia,keskustaa 17,7 prosenttia japerussuomalaisia noin 14 prosenttia.
#
# -----107-----
# Kolmannes takseista lopettanee
#
# Jopa tuhannet taksiyrittäjät saattavatjoutua lopettamaan liikennöintinsä ensikesän aikana.Taksiyrittäjien etujärjestön SuomenTaksiliiton toimitusjohtajan TimoKoskisen mukaan syynä ovat muun muassakoronapandemian hyydyttämä kysyntä jataksiliikennöintiluvan ehtojentiukentuminen.Taksialaa valvovan viranomaisenTraficomin mukaan useammalla kuin jokakolmannella taksiyrittäjällä on yhälain vaatima yrittäjäkoe suorittamatta.
#
# -----108-----
# STM: Rokottamattomilla suurin riski
#
# Rokottamattomat ovat syys-joulukuunaikana päätyneet koronavirustartunnanseurauksena erikoissairaanhoitoon 14kertaa todennäköisemmin ja tehohoitoon27 kertaa todennäköisemmin kuin kaksikertaa rokotetut, kertoo sosiaali- jaterveysministeriö.Ministeriön tiedotteen mukaan tautiinliittyviä kuolemia oli eiliseenmennessä ilmoitettu edeltävän kahdenviikon ajalta 138 kuollutta.Kuolleista 87 prosenttia oli yli70-vuotiaita.
#
# -----109-----
# Bussi kaatui kyljelleen Sipoossa
#
# Linja-auto kaatui kyljelleen aamullaennen puolta kymmentä SipoossaPaippistentiellä Itä-Uudellamaalla.Itä-Uudenmaan pelastuslaitoksen mukaanlinja-autossa oli neljä matkustajaa jakuljettaja.Autossa olleista yksi loukkaantunutkuljetettiin hoitoon. Toinen kaistaonnettomuuspaikalla on suljettu japoliisi ohjaa liikennettä.Ilmatieteen laitos antoi aamullavaroituksen erittäin liukkaastaajokelistä suureen osaan maatapohjoista Suomea lukuun ottamatta.
#
# -----110-----
# Koronatartuntoja 8368, kuolemia 28
#
# Suomessa on todettu eilisen jälkeen8368 uutta koronatartuntaa, kertooTerveyden ja hyvinvoinnin laitos THL.Tartunnoista reilut 3300 todettiinHelsingin ja Uudenmaansairaanhoitopiirin alueella.Sairaalahoidossa olevien määräilmoitetaan maanantaisin,keskiviikkoisin ja perjantaisin.Uusia koronavirukseen liittyviäkuolemantapauksia on THL:n mukaankirjattu 28.
#
# -----111-----
# Mysteeriporo olikin metsäpeura
#
# Helsinkiin eksynyt orpo mysteeripeuraon DNA-testin perusteella varmistunutmetsäpeuraksi.Asiasta kertoo Korkeasaarenvillieläinsairaala Twitter-tilillään.Villieläinsairaalan mukaan vasa onreipastunut ja syö jo hyvälläruokahalulla.Poliisi otti 8. tammikuuta kiinniHelsingissä liikkuneen vasan. Peurasaatiin kiinni ja vietiin hoitoonKorkeasaaren villieläinsairaalaantoipumaan voimakkaista stressioireista.
#
# -----112-----
# Tartunnoissa ollut tasaantumista
#
# Koronaviruksen tartunnoissa on olluthavaittavissa jonkinlaistatasaantumista Suomessa viime viikkoina,sanoo sosiaali- ja terveysministeriön(STM) johtava asiantuntija Liisa-MariaVoipio-Pulkki. Hän kertoi pandemiantilanteesta koronatilannekatsauksessatorstaina.Uusia koronatartuntoja raportoitiinSuomessa torstaina 8 368. Viimeisenviikon aikana maassa on todettu 55 500uutta koronatapausta. Koronaviruksenilmaantuvuus on yli 2 000 tartuntaasataatuhatta ihmistä kohden kahdessaviikossa.
#
# -----113-----
# Koululaisten käyttöön kotitestejä
#
# Huoltovarmuuskeskus (HVK) tiedottaahankkivansa koululaisten käyttöönensimmäiset erät koronakotitestejä.HVK tekee vähintään kuuden miljoonankotitestin hankinnan ministeriöiltäsaamansa toimeksiannon mukaisesti.Kotitestien toimitukset jakautuvatHVK:n mukaan useammalle viikolle.Ensimmäisiä testejä voidaan odottaakuntiin noin kolmen viikon kuluttua.Testit tulevat ensisijaisestiperusopetuksen, lukioiden jaammattioppilaitosten käyttöön.
#
# -----131-----
# Biden: Vuosi ollut täynnä haasteita
#
# Yhdysvaltain presidentti Joe Bidensanoo, että hänen ensimmäinen virka-vuotensa presidenttinä on ollut täynnähaasteita mutta sisältänyt myösmerkittäviä onnistumisia.Presidentti aloitti kello 23 Suomenaikaan alkaneen puheensa muistutta-malla, että 210 miljoonaa amerikka-laista on saanut koronarokotteen.Yhteiskunnan sulkutoimia tai koulujensulkemisia ei presidentin mukaan tullanäkemään. Bidenin mukaan testaukseenolisi kuitenkin pitänyt kiinnittääkriisin hoidossa enemmän huomiota. Tämätullaan Bidenin mukaan korjaamaan.
#
# -----132-----
# USA:n Blinken tapsi liittolaisiaan
#
# USA:n ulkoministeri Antony Blinkentapasi tänään Saksan, Ranskan jaBritannian ulkoministerit Berliinissä.Asialistalla oli mm. Venäjän uhkaanvastaaminen Ukrainassa.Blinken sanoi toivovansa, että Venäjänja Ukrainan väliset jännitteetsaataisiin ratkaistua diplomatialla.Hän sanoi, että tarvittaessa jännitteetvoidaan ratkaista liittolaisten voiminja hybridihyökkäyksen keinoin.Keinovalikoimassa on myös pakotteet.Blinkenin mukaan USA:n tavoite on estääVenäjän hyökkäys Ukrainaan.USA ontehnyt selväksi Venäjälle, ettähyökkäykseen vastattaisiin.
#
# -----133-----
# Ensimmäiset avustuslennot Tongaan
#
# Ensimmäiset avustuslennot ovat tulleetTongaan viisi päivää sen jälkeen, kuntulivuorenpurkaus ja sen laukaisematsunami aiheuttivat saarilla tuhoa.Uudesta-Seelannista saapui varhainaamulla Suomen aikaa apua tuonutkuljetuskone, ja myöhemmin laskeutuimyös australialainen avustuskone.Koneet toivat mm. generaattoreita jatelttatarpeita sekä suolaa vedestäpoistavia laitteita, sillä järistyspilasi suuren osan maan juomavedestä.Avustajat pyrkivät välttämään kontaktiatongalaisiin, sillä maa on tähän astivälttynyt koronavirukselta.
#
# -----134-----
# Kysely: Johnsonin suosio laskee
#
# Tuoreen mielipidekyselyn mukaan 60prosentilla briteistä on kielteinennäkemys pääministeri Boris Johnsonista.Johnsonin suosiota ovat nakertaneetpaljastukset juhlista, joitapääministerin virka-asunnossapidettiin samaan aikaan kun voimassaoli tiukkoja koronarajoituksia.Tutkimuslaitos Ipsosin tekemän kyselynvastaajista 57 prosenttia oli sitämieltä, että Johnson on huono pää-ministeri. Viikko sitten luku oli 51 %.Keskeisistä ministereistä hyvänarvosanan sai kyselyssä vainvaltiovarainministeri Rishi Sunak.
#
# -----135-----
# Venäjän laivasto harjoituksiin
#
# Venäjä järjestää valtavat laivasto-harjoitukset neljällä merellä, maanpuolustusministeriö kertoo.Harjoituksiin osallistuu yli 140sotalaivaa, niiden tukialuksia, yli 60ilma-alusta ja 10 000 sotilasta.Sotaharjoitukset pidetään tämän jahelmikuun aikana Atlantilla,Tyynellämerellä, Jäämerellä jaVälimerellä.Venäjän ja länsimaiden suhteet ovatkiristyneet äärimmilleen, kun Venäjäon sijoittanut joukkojeen lähelleUkrainan rajaa ja Valko-Venäjälle.
#
# -----136-----
# "Ex-paavi salli hyväksikäytön"
#
# Emerituspaavi Benedictus XVI eipuuttunut lasten seksuaaliseenhyväksikäyttöön, Saksan katolisenkirkon selvitys osoittaa.Benedictus oli paavi vuosina 2005 2008.Sitä ennen hänen nimensä oli JosephRatzinger ja hän työskenteli Müncheninja Freisingin arkkipiispana vuosina1977 1982.Tuolloin neljä pappia tai muuta kirkontyöntekijäö syyllistyi lastenseksuaaliseen hyväksikäyttöön, eikäarkkipiispa puuttunut siihen. Entinenpaavi kiistää jyrkästi vastuunsa.
#
# -----137-----
# Yli 3 miljoonaa tartuntaa päivässä
#
# Maailmassa on rekisteröity keskimäärinyli kolme miljoonaa uuttakoronatartuntaa päivittäin viime viikonaikana, kertoo uutistoimisto AFP. Se onennätysmäärä.Uusia tartuntoja on todettu keskimäärin3 095 971 vuorokaudessa tammikuun 13.ja 19. päivän aikana. Tartuntojen määräon noussut 17 prosenttia edeltävästäviikosta.Ennen omikronin yleistymistä maailmankeskimääräinen päivittäinentartuntaennätys oli noin 800 000huhtikuun loppupuolella 2021.
